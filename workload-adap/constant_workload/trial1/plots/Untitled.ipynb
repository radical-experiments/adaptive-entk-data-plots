# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob

# %%
src_file = glob.glob('../prof*.csv')

# %%
df = pd.read_csv(src_file[0])

# %%
print df.drop()
# Out:
#             uid   cores   ExecutingPending   AgentStagingOutput  \
# 0   unit.000018       8           144.2095             446.1383
# 1   unit.000019       8           144.1941             530.9999
# 2   unit.000030       8           449.3421             751.8484
# 3   unit.000031       8           474.7938             856.4683
# 4   unit.000036       1           536.1561             537.4157
# 5   unit.000037       1           545.3562             546.6362
# 6   unit.000034       1           470.3649             471.6918
# 7   unit.000033       1           451.9608             453.1555
# 8   unit.000010       1           136.9573             140.2911
# 9   unit.000011       1           136.6337             140.2641
# 10  unit.000012       1           136.8123             140.2797
# 11  unit.000013       1           136.8579             140.2835
# 12  unit.000014       1           136.6759             140.2682
# 13  unit.000015       1           136.9055             140.2873
# ...
